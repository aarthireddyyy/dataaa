# %%
print("hi")
# Out:
# hi

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv(r"C:/Users/reddy/Downloads/titanic.csv")

# %%
print(df.shape)
# Out:
# (891, 12)

# %%
print(df.dtypes)
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
print(df.describe())
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# Which columns have nulls?
# Age, Cabin, Enbarked
# Which dtypes look wrong to you ?
# Ticket is object , age in float
# Which columns has the most missing data ?
# cabin and age

# %%
for col in df.columns:
    print(f"\n{'='*40}")
    print(f"Columns: {col}")
    print(f"Data type: {df[col].dtype}")
    print(f"Nulls : {df[col].isnull().sum()}")
    print(f"Unique values: {df[col].nunique()}")
    if df[col].dtype == 'object':
        print(f"Top values : {df[col].value_counts().head(3).to_dict()}")
    else:
        print(f"Min/Max : {df[col].min()} / {df[col].max()}")
# Out:
# ...
# Columns: PassengerId
# Data type: int64
# Nulls : 0
# Unique values: 891
# Min/Max : 1 / 891
#
# ...
# Columns: Survived
# Data type: int64
# Nulls : 0
# Unique values: 2
# Min/Max : 0 / 1
#
# ...
# Columns: Pclass
# Data type: int64
# Nulls : 0
# Unique values: 3
# Min/Max : 1 / 3
#
# ...
# Columns: Name
# Data type: object
# Nulls : 0
# Unique values: 891
# Top values : {'Braund, Mr. Owen Harris': 1, 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)': 1, 'Heikkinen, Miss. Laina': 1}
#
# ...
# Columns: Sex
# Data type: object
# Nulls : 0
# Unique values: 2
# Top values : {'male': 577, 'female': 314}
#
# ...
# Columns: Age
# Data type: float64
# Nulls : 177
# Unique values: 88
# Min/Max : 0.42 / 80.0
#
# ...
# Columns: SibSp
# Data type: int64
# Nulls : 0
# Unique values: 7
# Min/Max : 0 / 8
#
# ...
# Columns: Parch
# Data type: int64
# Nulls : 0
# Unique values: 7
# Min/Max : 0 / 6
#
# ...
# Columns: Ticket
# Data type: object
# Nulls : 0
# Unique values: 681
# Top values : {'347082': 7, '1601': 7, 'CA. 2343': 7}
#
# ...
